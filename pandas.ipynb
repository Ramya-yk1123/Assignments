# %%
import pandas as pd
import numpy as np
data=pd.Series([1,2,3,4])
data
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
data=pd.Series([1,2,3,4],index=['a','b','c','d'])
data
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
data.name="numbers"
data
# Out:
# a    1
# b    2
# c    3
# d    4
# Name: numbers, dtype: int64

# %%
data.shape
# Out:
# (4,)

# %%
data.values
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
data.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
data[-2]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21532\2140106112.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data[-2]
# 3

# %%
data['a']
# Out:
# 1

# %%
data['b']
# Out:
# 2

# %%
data.iloc[0:5:2],data.loc['a':'d':2]
# Out:
# (a    1
#  c    3
#  Name: numbers, dtype: int64,
#  a    1
#  c    3
#  Name: numbers, dtype: int64)

# %%
data.loc[['a','d']]
# Out:
# a    1
# d    4
# Name: numbers, dtype: int64

# %%
dict={
    "usn":[1,2,3,4],
    "name":["Ramya","raju","priya","lakshmi"],
     "age":[23,29,22,21],
      "branch":["MCA","ITI","CS","SE"]
}
dict
# Out:
# {'usn': [1, 2, 3, 4],
#  'name': ['Ramya', 'raju', 'priya', 'lakshmi'],
#  'age': [23, 29, 22, 21],
#  'branch': ['MCA', 'ITI', 'CS', 'SE']}

# %%
df=pd.DataFrame(dict)
df
# Out:
#    usn     name  age branch
# 0    1    Ramya   23    MCA
# 1    2     raju   29    ITI
# 2    3    priya   22     CS
# 3    4  lakshmi   21     SE

# %%
data=pd.read_csv(r"C:\Users\User\Downloads\sample.csv")
data
# Out:
#     Unnamed: 0  EmpID   Name Department  Age  Salary  Experience JoiningDate  \
# 0            0    101    Ram         IT   25   50000           2  2021-01-15
# 1            1    102  Shyam         HR   30   45000           5  2019-03-10
# 2            2    103  Geeta    Finance   28   60000           4  2020-07-22
# 3            3    104  Anita         IT   35   75000          10  2015-09-30
# 4            4    105  Kiran         HR   32   52000           7  2018-06-12
# 5            5    106   John    Finance   29   58000           3  2021-11-05
# 6            6    107  Meena         IT   41   82000          15  2010-04-18
# 7            7    108  David         HR   26   48000           2  2022-02-14
# 8            8    109   Sara    Finance   38   61000          12  2013-12-01
# 9            9    110  Arjun         IT   27   54000           4  2020-08-19
# 10          10    111   Ravi         HR   33   47000           6  2017-05-23
# ...

# %%
data.head()
# Out:
#    Unnamed: 0  EmpID   Name Department  Age  Salary  Experience JoiningDate  \
# 0           0    101    Ram         IT   25   50000           2  2021-01-15
# 1           1    102  Shyam         HR   30   45000           5  2019-03-10
# 2           2    103  Geeta    Finance   28   60000           4  2020-07-22
# 3           3    104  Anita         IT   35   75000          10  2015-09-30
# 4           4    105  Kiran         HR   32   52000           7  2018-06-12
#
#         City  PerformanceScore
# 0  Bangalore               4.5
# 1     Mumbai               3.8
# 2      Delhi               4.2
# 3  Bangalore               4.9
# 4     Mumbai               4.1

# %%
data.head(7)
# Out:
#    Unnamed: 0  EmpID   Name Department  Age  Salary  Experience JoiningDate  \
# 0           0    101    Ram         IT   25   50000           2  2021-01-15
# 1           1    102  Shyam         HR   30   45000           5  2019-03-10
# 2           2    103  Geeta    Finance   28   60000           4  2020-07-22
# 3           3    104  Anita         IT   35   75000          10  2015-09-30
# 4           4    105  Kiran         HR   32   52000           7  2018-06-12
# 5           5    106   John    Finance   29   58000           3  2021-11-05
# 6           6    107  Meena         IT   41   82000          15  2010-04-18
#
#         City  PerformanceScore
# 0  Bangalore               4.5
# 1     Mumbai               3.8
# 2      Delhi               4.2
# 3  Bangalore               4.9
# 4     Mumbai               4.1
# 5      Delhi               3.9
# 6  Bangalore               4.8

# %%
data.describe()
# Out:
#        Unnamed: 0      EmpID        Age        Salary  Experience  \
# count    20.00000   20.00000  20.000000     20.000000   20.000000
# mean      9.50000  110.50000  32.700000  59875.000000    7.400000
# std       5.91608    5.91608   5.449288  13388.796377    4.615762
# min       0.00000  101.00000  25.000000  45000.000000    2.000000
# 25%       4.75000  105.75000  28.750000  50750.000000    4.000000
# 50%       9.50000  110.50000  31.500000  56500.000000    6.000000
# 75%      14.25000  115.25000  36.250000  61250.000000   10.250000
# max      19.00000  120.00000  45.000000  90000.000000   18.000000
#
#        PerformanceScore
# count         20.000000
# mean           4.190000
# std            0.415363
# min            3.500000
# 25%            3.900000
# 50%            4.150000
# 75%            4.425000
# max            4.900000

# %%
data.info
# Out:
# <bound method DataFrame.info of     Unnamed: 0  EmpID   Name Department  Age  Salary  Experience JoiningDate  \
# 0            0    101    Ram         IT   25   50000           2  2021-01-15
# 1            1    102  Shyam         HR   30   45000           5  2019-03-10
# 2            2    103  Geeta    Finance   28   60000           4  2020-07-22
# 3            3    104  Anita         IT   35   75000          10  2015-09-30
# 4            4    105  Kiran         HR   32   52000           7  2018-06-12
# 5            5    106   John    Finance   29   58000           3  2021-11-05
# 6            6    107  Meena         IT   41   82000          15  2010-04-18
# 7            7    108  David         HR   26   48000           2  2022-02-14
# 8            8    109   Sara    Finance   38   61000          12  2013-12-01
# 9            9    110  Arjun         IT   27   54000           4  2020-08-19
# 10          10    111   Ravi         HR   33   47000           6  2017-05-23
# ...

# %%
data.shape
# Out:
# (20, 10)

# %%
data.sample
# Out:
# <bound method NDFrame.sample of     Unnamed: 0  EmpID   Name Department  Age  Salary  Experience JoiningDate  \
# 0            0    101    Ram         IT   25   50000           2  2021-01-15
# 1            1    102  Shyam         HR   30   45000           5  2019-03-10
# 2            2    103  Geeta    Finance   28   60000           4  2020-07-22
# 3            3    104  Anita         IT   35   75000          10  2015-09-30
# 4            4    105  Kiran         HR   32   52000           7  2018-06-12
# 5            5    106   John    Finance   29   58000           3  2021-11-05
# 6            6    107  Meena         IT   41   82000          15  2010-04-18
# 7            7    108  David         HR   26   48000           2  2022-02-14
# 8            8    109   Sara    Finance   38   61000          12  2013-12-01
# 9            9    110  Arjun         IT   27   54000           4  2020-08-19
# 10          10    111   Ravi         HR   33   47000           6  2017-05-23
# ...

# %%
data.Name
# Out:
# 0       Ram
# 1     Shyam
# 2     Geeta
# 3     Anita
# 4     Kiran
# 5      John
# 6     Meena
# 7     David
# 8      Sara
# 9     Arjun
# 10     Ravi
# 11    Priya
# 12    Kunal
# 13    Sneha
# 14    Vijay
# 15     Neha
# 16     Amit
# 17    Pooja
# 18    Rahul
# 19    Divya
# Name: Name, dtype: object

# %%
data[["Name","Department","Salary"]]
# Out:
#      Name Department  Salary
# 0     Ram         IT   50000
# 1   Shyam         HR   45000
# 2   Geeta    Finance   60000
# 3   Anita         IT   75000
# 4   Kiran         HR   52000
# 5    John    Finance   58000
# 6   Meena         IT   82000
# 7   David         HR   48000
# 8    Sara    Finance   61000
# 9   Arjun         IT   54000
# 10   Ravi         HR   47000
# 11  Priya    Finance   59000
# 12  Kunal         IT   90000
# 13  Sneha         HR   51000
# 14  Vijay    Finance   62000
# 15   Neha         IT   88000
# 16   Amit         HR   53000
# 17  Pooja    Finance   57000
# 18  Rahul         IT   56000
# 19  Divya         HR   49500

# %%
type(data.Name)
# Out:
# pandas.core.series.Series

# %%
import numpy as np
import pandas as pd
data1=pd.read_csv("C:\\Users\\User\\Downloads\\test2.csv")
data1
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David   NaN         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
data1.loc[ : ,"Name":"Department"]
# Out:
#       Name   Age Department
# 0    Alice  25.0         HR
# 1      Bob  30.0         IT
# 2  Charlie  35.0    Finance
# 3    David   NaN         IT
# 4      Eve  29.0         HR
# 5    Alice  25.0         HR

# %%
data1.loc[1:3,"Name":"Department"]
# Out:
#       Name   Age Department
# 1      Bob  30.0         IT
# 2  Charlie  35.0    Finance
# 3    David   NaN         IT

# %%
data1.iloc[1:4,1:4]
# Out:
#       Name   Age Department
# 1      Bob  30.0         IT
# 2  Charlie  35.0    Finance
# 3    David   NaN         IT

# %%
data1.rename(columns={"Name":"N","Age":"A","Department":"D","Salary":"S"})
# Out:
#    Unnamed: 0        N     A        D        S
# 0           0    Alice  25.0       HR  50000.0
# 1           1      Bob  30.0       IT  60000.0
# 2           2  Charlie  35.0  Finance  70000.0
# 3           3    David   NaN       IT  62000.0
# 4           4      Eve  29.0       HR      NaN
# 5           5    Alice  25.0       HR  50000.0

# %%
data1
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David   NaN         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
data1.rename(columns={"Name":"N","Age":"A","Department":"D","Salary":"S"},inplace=True)

# %%
data1
# Out:
#    Unnamed: 0        N     A        D        S
# 0           0    Alice  25.0       HR  50000.0
# 1           1      Bob  30.0       IT  60000.0
# 2           2  Charlie  35.0  Finance  70000.0
# 3           3    David   NaN       IT  62000.0
# 4           4      Eve  29.0       HR      NaN
# 5           5    Alice  25.0       HR  50000.0

# %%
data1
# Out:
#          N     A        D        S
# 0    Alice  25.0       HR  50000.0
# 1      Bob  30.0       IT  60000.0
# 2  Charlie  35.0  Finance  70000.0
# 3    David   NaN       IT  62000.0
# 4      Eve  29.0       HR      NaN
# 5    Alice  25.0       HR  50000.0

# %%
data1.drop('Unnamed: 0',axis=1,inplace=True)
data1
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David   NaN         IT  62000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  50000.0

# %%
import numpy as np
import pandas as pd
data1=pd.read_csv("C:\\Users\\User\\Downloads\\test2.csv")
data1
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David   NaN         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
data1.drop('Unnamed: 0',axis=1,inplace=True)
data1
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David   NaN         IT  62000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  50000.0

# %%
data1["updated_salary"]=data1["Salary"]+50000

# %%
data1
# Out:
#       Name   Age Department   Salary  updated_salary
# 0    Alice  25.0         HR  50000.0        100000.0
# 1      Bob  30.0         IT  60000.0        110000.0
# 2  Charlie  35.0    Finance  70000.0        120000.0
# 3    David   NaN         IT  62000.0        112000.0
# 4      Eve  29.0         HR      NaN             NaN
# 5    Alice  25.0         HR  50000.0        100000.0

# %%
data1["updated_salary2"]=data1["Salary"].map(lambda x:x+10000)

# %%
data1
# Out:
#       Name   Age Department   Salary  updated_salary  updated_salary2
# 0    Alice  25.0         HR  50000.0        100000.0          60000.0
# 1      Bob  30.0         IT  60000.0        110000.0          70000.0
# 2  Charlie  35.0    Finance  70000.0        120000.0          80000.0
# 3    David   NaN         IT  62000.0        112000.0          72000.0
# 4      Eve  29.0         HR      NaN             NaN              NaN
# 5    Alice  25.0         HR  50000.0        100000.0          60000.0

# %%
type(data1.Age)
# Out:
# pandas.core.series.Series

# %%
data1.Age.dtype
# Out:
# dtype('float64')

# %%
data1.dropna(inplace=True)

# %%
data1
# Out:
#       Name   Age Department   Salary  updated_salary  updated_salary2
# 0    Alice  25.0         HR  50000.0        100000.0          60000.0
# 1      Bob  30.0         IT  60000.0        110000.0          70000.0
# 2  Charlie  35.0    Finance  70000.0        120000.0          80000.0
# 5    Alice  25.0         HR  50000.0        100000.0          60000.0

# %%
data1.Age.astype("int")
# Out:
# 0    25
# 1    30
# 2    35
# 5    25
# Name: Age, dtype: int32

# %%
data1
# Out:
#       Name   Age Department   Salary  updated_salary  updated_salary2
# 0    Alice  25.0         HR  50000.0        100000.0          60000.0
# 1      Bob  30.0         IT  60000.0        110000.0          70000.0
# 2  Charlie  35.0    Finance  70000.0        120000.0          80000.0
# 5    Alice  25.0         HR  50000.0        100000.0          60000.0

# %%
data1["Age"]>25
# Out:
# 0    False
# 1     True
# 2     True
# 5    False
# Name: Age, dtype: bool

# %%
data1[data1["Age"]>25]
# Out:
#       Name   Age Department   Salary  updated_salary  updated_salary2
# 1      Bob  30.0         IT  60000.0        110000.0          70000.0
# 2  Charlie  35.0    Finance  70000.0        120000.0          80000.0

# %%
data1["Age"]=data1["Age"].fillna(value=data1["Age"].mean())

# %%
data1
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David  28.8         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
data1["Salary"]=data1["Salary"].fillna(value=data1["Salary"].mean())

# %%
data1
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David  28.8         IT  62000.0
# 4           4      Eve  29.0         HR  58400.0
# 5           5    Alice  25.0         HR  50000.0

# %%
data1["Department"].value_counts()
# Out:
# Department
# HR         3
# IT         2
# Finance    1
# Name: count, dtype: int64

# %%
data1["Age"]=data1["Age"].fillna(method="ffill")
data1["Salary"]=data1["Salary"].fillna(method="bfill")
data1
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_69580\1743550497.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1["Age"]=data1["Age"].fillna(method="ffill")
# C:\Users\User\AppData\Local\Temp\ipykernel_69580\1743550497.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1["Salary"]=data1["Salary"].fillna(method="bfill")
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David  28.8         IT  62000.0
# 4           4      Eve  29.0         HR  58400.0
# 5           5    Alice  25.0         HR  50000.0

# %%
data1["updated_salary"]=data1["Salary"].apply(lambda x:x+500)
data1
# Out:
#    Unnamed: 0     Name   Age Department   Salary  updated_salary
# 0           0    Alice  25.0         HR  50000.0         50500.0
# 1           1      Bob  30.0         IT  60000.0         60500.0
# 2           2  Charlie  35.0    Finance  70000.0         70500.0
# 3           3    David  28.8         IT  62000.0         62500.0
# 4           4      Eve  29.0         HR  58400.0         58900.0
# 5           5    Alice  25.0         HR  50000.0         50500.0

# %%
data1["level"]=data1.apply(lambda row:"High" if row["Salary"]>60000 else "Low",axis=1)
data1
# Out:
#    Unnamed: 0     Name   Age Department   Salary  updated_salary level
# 0           0    Alice  25.0         HR  50000.0         50500.0   Low
# 1           1      Bob  30.0         IT  60000.0         60500.0   Low
# 2           2  Charlie  35.0    Finance  70000.0         70500.0  High
# 3           3    David  28.8         IT  62000.0         62500.0  High
# 4           4      Eve  29.0         HR  58400.0         58900.0   Low
# 5           5    Alice  25.0         HR  50000.0         50500.0   Low

# %%
data1.groupby("Department")["Salary"].mean()
# Out:
# Department
# Finance    70000.0
# HR         52800.0
# IT         61000.0
# Name: Salary, dtype: float64
